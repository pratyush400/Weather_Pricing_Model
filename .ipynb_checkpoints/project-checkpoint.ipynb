# %% [markdown]
# # Pricing Weather Derivatives using Perron-Frobenius Theorem and Eigendecomposition .
# ### Pratyush · Linear Algebra · Friday 20, 2026
#
# ---
#
# ## 1. Background
# I got the idea for this project through my independent study.  Throughout this study, I've been studying Steven Shreve's Stochastic Calculus for finance I: **The Binomial Asset Pricing Model**.

# %% [markdown]
# <img src="https://pictures.abebooks.com/inventory/md/md32407976969.jpg" width="150" height = "250" >

# %% [markdown]
# ---

# %% [markdown]
# So far in the book, I have covered <br>
#
# <ul>
# <b>Binomial No Arbitrage Pricing Model</b> : This talks about One and Two period Binomial and models and the condition for no arbitrage <u>(u>r+1>d>0)</u>
# <br><br>
#
# <b>Probability Theory on Coin Toss Space</b> : The chapter first does a good recap of finite probababilty space and conditional expectations. It later goes into <b> <u>Matingales </u></b> and <b> <u>Markov Processes </u></b>
#     <br><br>
# <b>State Prices</b> : Radon-Nikodym Derivative Process and Capital Asset Pricing Model <br><br>
#
# </ul>

# %% [markdown]
# ## 1. Proposal
# For my Linear Algebra I want to model the price of **Weather derivatives in Portland**

# %% [markdown]
# Weather derivatives are financial instruments whose payoff depends on meteorological
# parameters like temperature, rainfall, or snowfall. Now typically we can make a discrete 3-state chain for sunny, cloudy, and rainy and build a simple markov chain after which we can extract transition probabilities from <a href = "https://www.wunderground.com/history/monthly/us/or/portland"> weather data</a> to find the eignenvalue or equilibrium distribution vector  <br> <br> Portland, with it's diverse weather dynamics, would be an ideal location.<br>
# <br>
# However, The real weather is not so simple to model. Today's weather might depend on the past day or week or moth! So, assuming it depends on the last $k$ days, even with 3 weather states would require $3^k$ states so we would need an <u> an expanded state space and a large transition matrix</u> along with that we would also need to deal with a <u>transition matrix that varies with time. </u> <br>
# <br>

# %% [markdown]
# ## 2. Methods/Mathy Hard Part
#
# I am plan to use multiple computational tools as the derivative pricing would involve finding the expected payoff, that is, $$ \mathbb{E}[\text{payoff}]$$

# %% [markdown]
# which would then further lead to solving a linear system $$ (A - Q) \vec x = \vec b$$ where $Q$ is a submatrix of the transition matrix

# %% [markdown]
# Putting it all together, I plan to  model Portland's weather as a seasonal, non-homogeneous Markov chain whose transition matrix varies by month. The core mathematical challenge is analyzing the long-run behavior of a product of non-commuting transition matrices $A₁A₂⋯A₁₂$, and using the <u><b>Perron-Frobenius theorem </u></b> and <u><b> eigendecomposition </u></b> to price a temperature-based weather derivative as the expected discounted payoff under the stationary distribution.

# %% [markdown]
# <b>Tools:</b> I plan to use python(specifically jupyter notebooks) and use visualization and computattion libraries like:

# %%
import numpy
import matplotlib as plt
import math
